# %% [markdown]
# #Customers Churn
#
# The Telco company specializes in providing telephone and internet service to California. Thanks to its promotions, the company reached the number of 7,073 customers during the third quarter. However, it encounters serious difficulties in retaining its customers. In fact, the disengagement rate during this quarter was around 26.54%. This difficulty in retaining customers is reflected in the structure of the company's customer base:
#     •	25% of customers have less than 9 months of relationship
#     •	The median duration of the customer relationship with the company is 29 months, far from the 72 months relationship of the most loyal customers
#     •	75% of customers have a relationship duration of less than 55 months.
# Telco Management would like to commit to a loyalty policy by reducing the disengagement rate to less than 10% by:
#     •	Identification, upon entering a relationship, of the customers most likely to leave the company after the promotion period.
#     •	Concrete actions are likely to build loyalty among current customers.
# The Data Science team was entrusted with the mission of identifying the factors on which to act to retain existing customers and to develop a model to identify potential customers towards whom future promotions should be directed.
# This work involves the participation of:
#     •	General management for orientations
#     •	Director of the Customer Service team
#     •	Director of the Marketing team
#     •	Director of Technology
# It was produced using information available in the customer database which contains 33 variables for each customer.
# The approach adopted is:
#     •	To retain the 'Churn Label' column as an explanatory or independent variable
#     •	To determine to what extent each of the other variables allows predicting the explanatory variable
#     •	To retain the most relevant variables to develop a model based on the regression mode with the smallest absolute error
# The Data Science team will submit the following documents at the end of this study:
#     •	The Model Code
#     •	A two-page report:
#         o	Relating the conclusions of the different stages of data processing
#         o	Presenting the model
#         o	Recommendations
#         o	Possible considerations to consider when applying the conclusions
#     •	A slide deck

# %%
import os
os.listdir('.')
# Out:
# ['.ipynb_checkpoints',
#  '1687275588_Capstone_Two_Step_3__EDA.pdf',
#  'Customer_Churn.ipynb',
#  'Customer_Churn_part_2_corrected.ipynb',
#  'df_cust_churn_cleaned.csv',
#  'Logistic_Regression_Advanced_Case_Study',
#  'Untitled.ipynb']

# %%
import sys

# %%
import os

def find_file(filename, search_path):
    for root, dirs, files in os.walk(search_path):
        if filename in files:
            print(os.path.join(root, filename))

# Replace with the directory you want to search (e.g., home directory)
find_file('sb_utils.py', 'C:/Users/wgerm/OneDrive/Documents/GitHub')
# Out:
# C:/Users/wgerm/OneDrive/Documents/GitHub\DataScienceGuidedCapstone\Notebooks\library\sb_utils.py

# %%
sys.path.append('C:/Users/wgerm/OneDrive/Documents/GitHub/DataScienceGuidedCapstone/Notebooks')

# %%
#Code task 1#
#Import pandas, matplotlib.pyplot and seaborn 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

from library.sb_utils import save_file

# %% [markdown]
# 1.0 Load The Telco_customer_churn Data

# %%
#Code task 2#
cust_churn = pd.read_excel("C:/Users/wgerm/OneDrive/Documents/GitHub/wgermain24/archive CHURN/Telco_customer_churn.xlsx")

# %% [markdown]
# Auditing the data and display the first few records

# %%
# Code task 3#
cust_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7046 entries, 0 to 7045
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   float64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   float64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   float64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
#  16  Internet Service   7043 non-null   object
#  17  Online Security    7043 non-null   object
#  18  Online Backup      7043 non-null   object
#  19  Device Protection  7043 non-null   object
#  20  Tech Support       7043 non-null   object
#  21  Streaming TV       7043 non-null   object
#  22  Streaming Movies   7043 non-null   object
#  23  Contract           7043 non-null   object
#  24  Paperless Billing  7043 non-null   object
#  25  Payment Method     7043 non-null   object
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   object
#  29  Churn Value        7045 non-null   float64
#  30  Churn Score        7043 non-null   float64
#  31  CLTV               7043 non-null   float64
#  32  Churn Reason       1869 non-null   object
# dtypes: float64(9), object(24)
# memory usage: 1.8+ MB

# %% [markdown]
# The higher number of non-null rows of information in the 'Churn Value' column suggests the presence of null values in the dataset

# %%
# Drop of row with no Chun Label

# %%
cust_churn[['Churn Value']].isna().sum(axis=1)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7041    0
# 7042    0
# 7043    1
# 7044    0
# 7045    0
# Length: 7046, dtype: int64

# %%
#Code task 4#
# Visualize the head of the dataset
cust_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7046 entries, 0 to 7045
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   float64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   float64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   float64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
#  16  Internet Service   7043 non-null   object
#  17  Online Security    7043 non-null   object
#  18  Online Backup      7043 non-null   object
#  19  Device Protection  7043 non-null   object
#  20  Tech Support       7043 non-null   object
#  21  Streaming TV       7043 non-null   object
#  22  Streaming Movies   7043 non-null   object
#  23  Contract           7043 non-null   object
#  24  Paperless Billing  7043 non-null   object
#  25  Payment Method     7043 non-null   object
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   object
#  29  Churn Value        7045 non-null   float64
#  30  Churn Score        7043 non-null   float64
#  31  CLTV               7043 non-null   float64
#  32  Churn Reason       1869 non-null   object
# dtypes: float64(9), object(24)
# memory usage: 1.8+ MB

# %% [markdown]
# 2.0 Exploring The Data

# %% [markdown]
# 2.1 Number of Missing Values By column

# %%
#Code task 5#
#Count missing values in number and percetage and present the result in a single table
missing_values = pd.concat([cust_churn.isnull().sum(), 100*cust_churn.isnull().mean()],axis=1)
missing_values.columns =['count','%']
missing_values.sort_values(by="%", ascending=False)
# Out:
#                    count          %
# Churn Reason        5177  73.474312
# Count                  3   0.042577
# CLTV                   3   0.042577
# Churn Score            3   0.042577
# Churn Label            3   0.042577
# Total Charges          3   0.042577
# Monthly Charges        3   0.042577
# Payment Method         3   0.042577
# Paperless Billing      3   0.042577
# Contract               3   0.042577
# Streaming Movies       3   0.042577
# Streaming TV           3   0.042577
# Tech Support           3   0.042577
# Device Protection      3   0.042577
# Online Backup          3   0.042577
# Online Security        3   0.042577
# CustomerID             3   0.042577
# Multiple Lines         3   0.042577
# Phone Service          3   0.042577
# Tenure Months          3   0.042577
# Dependents             3   0.042577
# Partner                3   0.042577
# Senior Citizen         3   0.042577
# Gender                 3   0.042577
# Longitude              3   0.042577
# Latitude               3   0.042577
# Lat Long               3   0.042577
# Zip Code               3   0.042577
# City                   3   0.042577
# State                  3   0.042577
# Country                3   0.042577
# Internet Service       3   0.042577
# Churn Value            1   0.014192

# %% [markdown]
# As mentioned above, the columns are well referenced. The missing information in the Churn reason column can be explained and can be addressed later

# %% [markdown]
# 2.2 Categorical Features

# %%
#Code task 6#
#Select columns of dtype 'object'
cust_churn.select_dtypes('object').T
# Out:
#                                            0                      1     \
# CustomerID                           3668-QPYBK             9237-HQITU
# Country                           United States          United States
# State                                California             California
# City                                Los Angeles            Los Angeles
# Lat Long                 33.964131, -118.272783  34.059281, -118.30742
# Gender                                     Male                 Female
# Senior Citizen                               No                     No
# Partner                                      No                     No
# Dependents                                   No                    Yes
# Phone Service                               Yes                    Yes
# Multiple Lines                               No                     No
# Internet Service                            DSL            Fiber optic
# Online Security                             Yes                     No
# Online Backup                               Yes                     No
# Device Protection                            No                     No
# Tech Support                                 No                     No
# Streaming TV                                 No                     No
# Streaming Movies                             No                     No
# Contract                         Month-to-month         Month-to-month
# Paperless Billing                           Yes                    Yes
# Payment Method                     Mailed check       Electronic check
# Total Charges                            108.15                 151.65
# Churn Label                                 Yes                    Yes
# Churn Reason       Competitor made better offer                  Moved
#
#                                      2                       3     \
# CustomerID                     9305-CDSKC              7892-POOKP
# Country                     United States           United States
# State                          California              California
# City                          Los Angeles             Los Angeles
# Lat Long           34.048013, -118.293953  34.062125, -118.315709
# Gender                             Female                  Female
# Senior Citizen                         No                      No
# Partner                                No                     Yes
# Dependents                            Yes                     Yes
# Phone Service                         Yes                     Yes
# Multiple Lines                        Yes                     Yes
# Internet Service              Fiber optic             Fiber optic
# Online Security                        No                      No
# Online Backup                          No                      No
# Device Protection                     Yes                     Yes
# Tech Support                           No                     Yes
# Streaming TV                          Yes                     Yes
# Streaming Movies                      Yes                     Yes
# Contract                   Month-to-month          Month-to-month
# Paperless Billing                     Yes                     Yes
# Payment Method           Electronic check        Electronic check
# Total Charges                       820.5                 3046.05
# Churn Label                           Yes                     Yes
# Churn Reason                        Moved                   Moved
#
#                                             4     \
# CustomerID                            0280-XJGEX
# Country                            United States
# State                                 California
# City                                 Los Angeles
# Lat Long                  34.039224, -118.266293
# Gender                                      Male
# Senior Citizen                                No
# Partner                                       No
# Dependents                                   Yes
# Phone Service                                Yes
# Multiple Lines                               Yes
# Internet Service                     Fiber optic
# Online Security                               No
# Online Backup                                Yes
# Device Protection                            Yes
# Tech Support                                  No
# Streaming TV                                 Yes
# Streaming Movies                             Yes
# Contract                          Month-to-month
# Paperless Billing                            Yes
# Payment Method         Bank transfer (automatic)
# Total Charges                             5036.3
# Churn Label                                  Yes
# Churn Reason       Competitor had better devices
#
#                                                         5     \
# CustomerID                                        4190-MFLUW
# Country                                        United States
# State                                             California
# City                                             Los Angeles
# Lat Long                              34.066367, -118.309868
# Gender                                                Female
# Senior Citizen                                            No
# Partner                                                  Yes
# Dependents                                                No
# Phone Service                                            Yes
# Multiple Lines                                            No
# Internet Service                                         DSL
# Online Security                                           No
# Online Backup                                             No
# Device Protection                                        Yes
# Tech Support                                             Yes
# Streaming TV                                              No
# Streaming Movies                                          No
# Contract                                      Month-to-month
# Paperless Billing                                         No
# Payment Method                       Credit card (automatic)
# Total Charges                                         528.35
# Churn Label                                              Yes
# Churn Reason       Competitor offered higher download speeds
#
#                                            6                             7     \
# CustomerID                           8779-QRDMV                    1066-JKSGK
# Country                           United States                 United States
# State                                California                    California
# City                                Los Angeles                   Los Angeles
# Lat Long                  34.02381, -118.156582        34.066303, -118.435479
# Gender                                     Male                          Male
# Senior Citizen                              Yes                            No
# Partner                                      No                            No
# Dependents                                   No                            No
# Phone Service                                No                           Yes
# Multiple Lines                 No phone service                            No
# Internet Service                            DSL                            No
# Online Security                              No           No internet service
# Online Backup                                No           No internet service
# Device Protection                           Yes           No internet service
# Tech Support                                 No           No internet service
# Streaming TV                                 No           No internet service
# Streaming Movies                            Yes           No internet service
# Contract                         Month-to-month                Month-to-month
# Paperless Billing                           Yes                            No
# Payment Method                 Electronic check                  Mailed check
# Total Charges                             39.65                         20.15
# Churn Label                                 Yes                           Yes
# Churn Reason       Competitor offered more data  Competitor made better offer
#
#                                             8     \
# CustomerID                            6467-CHFZW
# Country                            United States
# State                                 California
# City                                 Los Angeles
# Lat Long                  34.099869, -118.326843
# Gender                                      Male
# Senior Citizen                                No
# Partner                                      Yes
# Dependents                                   Yes
# Phone Service                                Yes
# Multiple Lines                               Yes
# Internet Service                     Fiber optic
# Online Security                               No
# Online Backup                                Yes
# Device Protection                             No
# Tech Support                                  No
# Streaming TV                                 Yes
# Streaming Movies                             Yes
# Contract                          Month-to-month
# Paperless Billing                            Yes
# Payment Method                  Electronic check
# Total Charges                            4749.15
# Churn Label                                  Yes
# Churn Reason       Competitor had better devices
#
#                                             9     ...  \
# CustomerID                            8665-UTDHZ  ...
# Country                            United States  ...
# State                                 California  ...
# City                                 Los Angeles  ...
# Lat Long                  34.089953, -118.294824  ...
# Gender                                      Male  ...
# Senior Citizen                                No  ...
# Partner                                      Yes  ...
# Dependents                                    No  ...
# Phone Service                                 No  ...
# Multiple Lines                  No phone service  ...
# Internet Service                             DSL  ...
# Online Security                               No  ...
# Online Backup                                Yes  ...
# Device Protection                             No  ...
# Tech Support                                  No  ...
# Streaming TV                                  No  ...
# Streaming Movies                              No  ...
# Contract                          Month-to-month  ...
# Paperless Billing                             No  ...
# Payment Method                  Electronic check  ...
# Total Charges                               30.2  ...
# Churn Label                                  Yes  ...
# Churn Reason       Competitor had better devices  ...
#
#                                         7036                    7037  \
# CustomerID                        8456-QDAVC              7750-EYXWZ
# Country                        United States           United States
# State                             California              California
# City                             Winterhaven            Yucca Valley
# Lat Long              32.852947, -114.850784  34.159534, -116.425984
# Gender                                  Male                  Female
# Senior Citizen                            No                      No
# Partner                                   No                      No
# Dependents                                No                      No
# Phone Service                            Yes                      No
# Multiple Lines                            No        No phone service
# Internet Service                 Fiber optic                     DSL
# Online Security                           No                      No
# Online Backup                             No                     Yes
# Device Protection                         No                     Yes
# Tech Support                              No                     Yes
# Streaming TV                             Yes                     Yes
# Streaming Movies                          No                     Yes
# Contract                      Month-to-month                One year
# Paperless Billing                        Yes                      No
# Payment Method     Bank transfer (automatic)        Electronic check
# Total Charges                         1495.1                   743.3
# Churn Label                               No                      No
# Churn Reason                             NaN                     NaN
#
#                                         7038                    7039  \
# CustomerID                        2569-WGERO              6840-RESVB
# Country                        United States           United States
# State                             California              California
# City                                 Landers                Adelanto
# Lat Long              34.341737, -116.539416  34.667815, -117.536183
# Gender                                Female                    Male
# Senior Citizen                            No                      No
# Partner                                   No                     Yes
# Dependents                                No                     Yes
# Phone Service                            Yes                     Yes
# Multiple Lines                            No                     Yes
# Internet Service                          No                     DSL
# Online Security          No internet service                     Yes
# Online Backup            No internet service                      No
# Device Protection        No internet service                     Yes
# Tech Support             No internet service                     Yes
# Streaming TV             No internet service                     Yes
# Streaming Movies         No internet service                     Yes
# Contract                            Two year                One year
# Paperless Billing                        Yes                     Yes
# Payment Method     Bank transfer (automatic)            Mailed check
# Total Charges                         1419.4                  1990.5
# Churn Label                               No                      No
# Churn Reason                             NaN                     NaN
#
#                                       7040                 7041  \
# CustomerID                      2234-XADUH           4801-JZAZL
# Country                      United States        United States
# State                           California           California
# City                                 Amboy         Angelus Oaks
# Lat Long            34.559882, -115.637164  34.1678, -116.86433
# Gender                              Female               Female
# Senior Citizen                          No                   No
# Partner                                Yes                  Yes
# Dependents                             Yes                  Yes
# Phone Service                          Yes                   No
# Multiple Lines                         Yes     No phone service
# Internet Service               Fiber optic                  DSL
# Online Security                         No                  Yes
# Online Backup                          Yes                   No
# Device Protection                      Yes                   No
# Tech Support                            No                   No
# Streaming TV                           Yes                   No
# Streaming Movies                       Yes                   No
# Contract                          One year       Month-to-month
# Paperless Billing                      Yes                  Yes
# Payment Method     Credit card (automatic)     Electronic check
# Total Charges                       7362.9               346.45
# Churn Label                             No                   No
# Churn Reason                           NaN                  NaN
#
#                                         7042 7043 7044 7045
# CustomerID                        3186-AJIEK  NaN  NaN  NaN
# Country                        United States  NaN  NaN  NaN
# State                             California  NaN  NaN  NaN
# City                            Apple Valley  NaN  NaN  NaN
# Lat Long              34.424926, -117.184503  NaN  NaN  NaN
# Gender                                  Male  NaN  NaN  NaN
# Senior Citizen                            No  NaN  NaN  NaN
# Partner                                   No  NaN  NaN  NaN
# Dependents                                No  NaN  NaN  NaN
# Phone Service                            Yes  NaN  NaN  NaN
# Multiple Lines                            No  NaN  NaN  NaN
# Internet Service                 Fiber optic  NaN  NaN  NaN
# Online Security                          Yes  NaN  NaN  NaN
# Online Backup                             No  NaN  NaN  NaN
# Device Protection                        Yes  NaN  NaN  NaN
# Tech Support                             Yes  NaN  NaN  NaN
# Streaming TV                             Yes  NaN  NaN  NaN
# Streaming Movies                         Yes  NaN  NaN  NaN
# Contract                            Two year  NaN  NaN  NaN
# Paperless Billing                        Yes  NaN  NaN  NaN
# Payment Method     Bank transfer (automatic)  NaN  NaN  NaN
# Total Charges                         6844.5  NaN  NaN  NaN
# Churn Label                               No  NaN  NaN  NaN
# Churn Reason                             NaN  NaN  NaN  NaN
#
# [24 rows x 7046 columns]

# %% [markdown]
# 2.2.1 Unique Customers

# %%
#Code task 7#
cust_churn['CustomerID'].value_counts().head()
# Out:
# CustomerID
# 3668-QPYBK    1
# 9169-BSVIN    1
# 0206-OYVOC    1
# 6418-HNFED    1
# 8805-JNRAZ    1
# Name: count, dtype: int64

# %% [markdown]
# There is no duplication of customers as the value_counts rank the data from the greater to the lower. So, each row is unique.

# %% [markdown]
# 2.2.2 Country, State And City

# %%
#Code task 8#
cust_churn_location = cust_churn[['Country','State','City']].value_counts().sort_values(ascending=False)
cust_churn_location
# Out:
# Country        State       City
# United States  California  Los Angeles            305
#                            San Diego              150
#                            San Jose               112
#                            Sacramento             108
#                            San Francisco          104
#                                                  ...
#                            Running Springs          4
#                            San Quentin              4
#                            San Juan Capistrano      4
#                            Volcano                  4
#                            Zenia                    4
# Name: count, Length: 1129, dtype: int64

# %% [markdown]
# The data relate all to the State of California in United States. The columns "Country" and "State" contain the same information for all rows, so are not relevant

# %%
# Drop the columns 'Country' and 'State'
cust_churn.drop(['Country', 'State'], inplace=True, axis=1)
print(cust_churn.columns)
# Out:
# Index(['CustomerID', 'Count', 'City', 'Zip Code', 'Lat Long', 'Latitude',
#        'Longitude', 'Gender', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure Months', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn Label',
#        'Churn Value', 'Churn Score', 'CLTV', 'Churn Reason'],
#       dtype='object')

# %% [markdown]
# 2.2.3 Unique City

# %%
## Code task 9#
# Call the numique method on the column 'City" to check the unique number of cities
state_churn_num_city =cust_churn['City'].nunique()
state_churn_num_city
# Out:
# 1129

# %% [markdown]
# California is made up of 482 cities. Some places register as 'City' in the Database may not be.

# %%
## code task 10#
## Downloading the list of the cities within California to identify the places wrongly register as City
california_city = pd.read_excel("C:/Users/wgerm/OneDrive/Documents/GitHub/wgermain24/archive CHURN/California_city.xlsx")

# %%
#Code task 11#
#Call the info() method on California_city to have a big picture of the columns
california_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Entity Name                 480 non-null    object
#  1   Entity ID                   480 non-null    int64
#  2   Entity Type                 480 non-null    object
#  3   County Name                 480 non-null    object
#  4   City                        480 non-null    object
#  5   State                       480 non-null    object
#  6   Zip                         480 non-null    object
#  7   Estimated Population        480 non-null    int64
#  8   Class Data                  480 non-null    object
#  9   Fiscal Year End             480 non-null    int64
#  10  Paper Report Due Date       480 non-null    int64
#  11  Electronic Report Due Date  480 non-null    int64
# dtypes: int64(5), object(7)
# memory usage: 45.1+ KB

# %%
#Code task 12#
#Check on the names of the columns
california_city.columns
# Out:
# Index(['Entity Name', 'Entity ID', 'Entity Type', 'County Name', 'City',
#        'State', 'Zip', 'Estimated Population', 'Class Data', 'Fiscal Year End',
#        'Paper Report Due Date', 'Electronic Report Due Date'],
#       dtype='object')

# %%
#Code task 13# 
#Call the head method on California_city to print several rows of the data
california_city.head()
# Out:
#     Entity Name  Entity ID Entity Type     County Name          City State  \
# 0      Adelanto       1128         CIT  San Bernardino      Adelanto    CA
# 1  Agoura Hills       1129         CIT     Los Angeles  Agoura Hills    CA
# 2       Alameda       1130         CIT         Alameda       Alameda    CA
# 3        Albany       1131         CIT         Alameda        Albany    CA
# 4      Alhambra       1132         CIT     Los Angeles      Alhambra    CA
#
#           Zip  Estimated Population   Class Data  Fiscal Year End  \
# 0       92301                 36357    Chartered              630
# 1       91301                 19771  General Law              630
# 2       94501                 77784    Chartered              630
# 3  94706-2226                 21648    Chartered              630
# 4  91802-2351                 81834    Chartered              630
#
#    Paper Report Due Date  Electronic Report Due Date
# 0                    131                         131
# 1                    131                         131
# 2                    131                         131
# 3                    131                         131
# 4                    131                         131

# %%
#Code task 14#
#Select some relevant columns of california_city and define a new DataFrame with those columns
#print several rows of the new DataFrame by using the head method
california_cities = california_city.loc[ :, ['Entity ID', 'County Name','City','Zip','Estimated Population']].copy()
california_cities.columns = ['Entity ID', 'County Name','City','Zip','Estimated Population']
california_cities.head()
# Out:
#    Entity ID     County Name          City         Zip  Estimated Population
# 0       1128  San Bernardino      Adelanto       92301                 36357
# 1       1129     Los Angeles  Agoura Hills       91301                 19771
# 2       1130         Alameda       Alameda       94501                 77784
# 3       1131         Alameda        Albany  94706-2226                 21648
# 4       1132     Los Angeles      Alhambra  91802-2351                 81834

# %%
#Code task 15#
#Find the cities in `cust_churn` that are not in `california_cities`
#Using: set(list1) - set(list2) is an easy way to get items in list1 that are not in list2
missing_cities = set(cust_churn.City) - set(california_cities.City)
missing_cities
# Out:
# {'Acampo',
#  'Acton',
#  'Adin',
#  'Aguanga',
#  'Ahwahnee',
#  'Alamo',
#  'Albion',
#  'Alderpoint',
#  'Alleghany',
#  'Alpaugh',
#  'Alpine',
#  'Alta',
#  'Altadena',
#  'Alviso',
#  'Amador City',
#  'Amboy',
#  'Angelus Oaks',
#  'Angwin',
#  'Annapolis',
#  'Antelope',
#  'Anza',
#  'Applegate',
#  'Aptos',
#  'Arbuckle',
#  'Armona',
#  'Arnold',
#  'Aromas',
#  'Auberry',
#  'Avery',
#  'Avila Beach',
#  'Badger',
#  'Baker',
#  'Ballico',
#  'Bangor',
#  'Bass Lake',
#  'Bayside',
#  'Beale Afb',
#  'Bella Vista',
#  'Belvedere Tiburon',
#  'Ben Lomond',
#  'Benton',
#  'Berry Creek',
#  'Bethel Island',
#  'Bieber',
#  'Big Bar',
#  'Big Bear City',
#  'Big Bend',
#  'Big Creek',
#  'Big Oak Flat',
#  'Big Pine',
#  'Big Sur',
#  'Biola',
#  'Birds Landing',
#  'Blairsden Graeagle',
#  'Blocksburg',
#  'Bloomington',
#  'Bodega',
#  'Bodega Bay',
#  'Bodfish',
#  'Bolinas',
#  'Bonita',
#  'Bonsall',
#  'Boonville',
#  'Boron',
#  'Borrego Springs',
#  'Boulder Creek',
#  'Boulevard',
#  'Bradley',
#  'Branscomb',
#  'Bridgeport',
#  'Bridgeville',
#  'Brookdale',
#  'Brooks',
#  'Browns Valley',
#  'Brownsville',
#  'Burney',
#  'Burnt Ranch',
#  'Burson',
#  'Butte City',
#  'Buttonwillow',
#  'Byron',
#  'Cabazon',
#  'Caliente',
#  'California Hot Springs',
#  'Callahan',
#  'Calpine',
#  'Cambria',
#  'Camino',
#  'Camp Nelson',
#  'Campo',
#  'Campo Seco',
#  'Camptonville',
#  'Canby',
#  'Canoga Park',
#  'Cantua Creek',
#  'Canyon Country',
#  'Canyon Dam',
#  'Capay',
#  'Capistrano Beach',
#  'Cardiff By The Sea',
#  'Carlotta',
#  'Carmel',
#  'Carmel By The Sea',
#  'Carmel Valley',
#  'Carmichael',
#  'Carnelian Bay',
#  'Caruthers',
#  'Casmalia',
#  'Caspar',
#  'Cassel',
#  'Castaic',
#  'Castella',
#  'Castro Valley',
#  'Castroville',
#  'Catheys Valley',
#  'Cayucos',
#  'Cazadero',
#  'Cedar Glen',
#  'Cedarville',
#  'Challenge',
#  'Chatsworth',
#  'Chester',
#  'Chilcoot',
#  'Chualar',
#  'Clarksburg',
#  'Clearlake Oaks',
#  'Clements',
#  'Clio',
#  'Clipper Mills',
#  'Coarsegold',
#  'Cobb',
#  'Coleville',
#  'Columbia',
#  'Comptche',
#  'Cool',
#  'Copperopolis',
#  'Corona Del Mar',
#  'Cottonwood',
#  'Coulterville',
#  'Courtland',
#  'Covelo',
#  'Crescent Mills',
#  'Cressey',
#  'Crestline',
#  'Creston',
#  'Crockett',
#  'Crows Landing',
#  'Cutler',
#  'Daggett',
#  'Darwin',
#  'Davenport',
#  'Davis Creek',
#  'Death Valley',
#  'Deer Park',
#  'Del Rey',
#  'Delhi',
#  'Denair',
#  'Descanso',
#  'Desert Center',
#  'Diamond Springs',
#  'Dillon Beach',
#  'Dobbins',
#  'Dos Rios',
#  'Douglas City',
#  'Downieville',
#  'Doyle',
#  'Ducor',
#  'Dulzura',
#  'Duncans Mills',
#  'Dunlap',
#  'Dunnigan',
#  'Durham',
#  'Dutch Flat',
#  'Eagleville',
#  'Earlimart',
#  'Earp',
#  'Echo Lake',
#  'Edwards',
#  'El Dorado',
#  'El Dorado Hills',
#  'El Nido',
#  'El Portal',
#  'El Sobrante',
#  'Eldridge',
#  'Elk',
#  'Elk Creek',
#  'Elmira',
#  'Elverta',
#  'Emigrant Gap',
#  'Encino',
#  'Esparto',
#  'Essex',
#  'Fair Oaks',
#  'Fall River Mills',
#  'Fallbrook',
#  'Farmington',
#  'Fawnskin',
#  'Fellows',
#  'Felton',
#  'Fiddletown',
#  'Fields Landing',
#  'Fish Camp',
#  'Five Points',
#  'Flournoy',
#  'Foothill Ranch',
#  'Forbestown',
#  'Forest Falls',
#  'Forest Knolls',
#  'Forest Ranch',
#  'Foresthill',
#  'Forestville',
#  'Forks Of Salmon',
#  'Fort Bidwell',
#  'Fort Irwin',
#  'Frazier Park',
#  'Freedom',
#  'French Camp',
#  'French Gulch',
#  'Friant',
#  'Fulton',
#  'Garberville',
#  'Garden Valley',
#  'Gasquet',
#  'Gazelle',
#  'Georgetown',
#  'Gerber',
#  'Geyserville',
#  'Glen Ellen',
#  'Glencoe',
#  'Glenhaven',
#  'Glenn',
#  'Glennville',
#  'Gold Run',
#  'Goodyears Bar',
#  'Granada Hills',
#  'Granite Bay',
#  'Graton',
#  'Green Valley Lake',
#  'Greenbrae',
#  'Greenview',
#  'Greenville',
#  'Greenwood',
#  'Grenada',
#  'Grimes',
#  'Grizzly Flats',
#  'Groveland',
#  'Gualala',
#  'Guatay',
#  'Guerneville',
#  'Guinda',
#  'Gustine',
#  'Hacienda Heights',
#  'Hamilton City',
#  'Happy Camp',
#  'Harbor City',
#  'Hat Creek',
#  'Hathaway Pines',
#  'Hayfork',
#  'Heber',
#  'Helendale',
#  'Helm',
#  'Herald',
#  'Herlong',
#  'Hickman',
#  'Hilmar',
#  'Hinkley',
#  'Hollister',
#  'Homeland',
#  'Homewood',
#  'Honeydew',
#  'Hood',
#  'Hoopa',
#  'Hopland',
#  'Hornbrook',
#  'Hornitos',
#  'Hume',
#  'Hyampom',
#  'Hydesville',
#  'Idyllwild',
#  'Igo',
#  'Independence',
#  'Inverness',
#  'Inyokern',
#  'Ivanhoe',
#  'Jacumba',
#  'Jamestown',
#  'Jamul',
#  'Janesville',
#  'Jenner',
#  'Johannesburg',
#  'Jolon',
#  'Joshua Tree',
#  'Julian',
#  'Junction City',
#  'June Lake',
#  'Keeler',
#  'Keene',
#  'Kelseyville',
#  'Kenwood',
#  'Kernville',
#  'Kettleman City',
#  'Keyes',
#  'Kings Beach',
#  'Kirkwood',
#  'Klamath',
#  'Klamath River',
#  'Kneeland',
#  'Knights Landing',
#  'Korbel',
#  'Kyburz',
#  'La Crescenta',
#  'La Grange',
#  'La Honda',
#  'La Jolla',
#  'Ladera Ranch',
#  'Lagunitas',
#  'Lake Arrowhead',
#  'Lake City',
#  'Lake Hughes',
#  'Lake Isabella',
#  'Lakehead',
#  'Lakeshore',
#  'Lakeside',
#  'Lamont',
#  'Landers',
#  'Laton',
#  'Laytonville',
#  'Le Grand',
#  'Lebec',
#  'Lee Vining',
#  'Leggett',
#  'Lemon Cove',
#  'Lewiston',
#  'Likely',
#  'Linden',
#  'Litchfield',
#  'Little River',
#  'Littlerock',
#  'Llano',
#  'Lockeford',
#  'Lockwood',
#  'Loleta',
#  'Loma Mar',
#  'Lone Pine',
#  'Long Barn',
#  'Lookout',
#  'Los Alamos',
#  'Los Molinos',
#  'Los Olivos',
#  'Los Osos',
#  'Lost Hills',
#  'Lotus',
#  'Lower Lake',
#  'Lucerne',
#  'Lucerne Valley',
#  'Ludlow',
#  'Lytle Creek',
#  'Macdoel',
#  'Mad River',
#  'Madeline',
#  'Madison',
#  'Magalia',
#  'Manchester',
#  'Manton',
#  'March Air Reserve Base',
#  'Marina Del Rey',
#  'Mariposa',
#  'Markleeville',
#  'Marshall',
#  'Mather',
#  'Maxwell',
#  'Mc Farland',
#  'Mc Kittrick',
#  'Mcarthur',
#  'Mccloud',
#  'Mckinleyville',
#  'Meadow Valley',
#  'Meadow Vista',
#  'Mecca',
#  'Mendocino',
#  'Mentone',
#  'Meridian',
#  'Mi Wuk Village',
#  'Middletown',
#  'Midpines',
#  'Midway City',
#  'Milford',
#  'Mill Creek',
#  'Millville',
#  'Mineral',
#  'Mira Loma',
#  'Miramonte',
#  'Miranda',
#  'Mission Hills',
#  'Mojave',
#  'Mokelumne Hill',
#  'Montara',
#  'Monte Rio',
#  'Montgomery Creek',
#  'Montrose',
#  'Morongo Valley',
#  'Moss Beach',
#  'Moss Landing',
#  'Mount Hamilton',
#  'Mount Hermon',
#  'Mount Laguna',
#  'Mount Shasta',
#  'Mountain Center',
#  'Mountain Ranch',
#  'Mt Baldy',
#  'Murphys',
#  'Myers Flat',
#  'Navarro',
#  'New Cuyama',
#  'Newberry Springs',
#  'Newbury Park',
#  'Newcastle',
#  'Newhall',
#  'Newport Coast',
#  'Nicasio',
#  'Nice',
#  'Nicolaus',
#  'Niland',
#  'Nipomo',
#  'Nipton',
#  'North Fork',
#  'North Highlands',
#  'North Hills',
#  'North Hollywood',
#  'North Palm Springs',
#  'North San Juan',
#  'Northridge',
#  'Novato',
#  'Nubieber',
#  'Nuevo',
#  'O Neals',
#  'Oak Park',
#  'Oak Run',
#  'Oak View',
#  'Oakhurst',
#  'Occidental',
#  'Oceano',
#  'Ocotillo',
#  'Olancha',
#  'Old Station',
#  'Olema',
#  'Olivehurst',
#  'Olympic Valley',
#  'Onyx',
#  'Orangevale',
#  'Oregon House',
#  'Orick',
#  'Orleans',
#  'Oro Grande',
#  'Orosi',
#  'Pacific Palisades',
#  'Pacoima',
#  'Paicines',
#  'Pala',
#  'Palermo',
#  'Palo Cedro',
#  'Palo Verde',
#  'Palomar Mountain',
#  'Palos Verdes Peninsula',
#  'Panorama City',
#  'Parker Dam',
#  'Paskenta',
#  'Paso Robles',
#  'Pauma Valley',
#  'Paynes Creek',
#  'Pearblossom',
#  'Pebble Beach',
#  'Penn Valley',
#  'Penngrove',
#  'Penryn',
#  'Pescadero',
#  'Petrolia',
#  'Phelan',
#  'Phillipsville',
#  'Philo',
#  'Piercy',
#  'Pilot Hill',
#  'Pine Grove',
#  'Pine Valley',
#  'Pinecrest',
#  'Pinon Hills',
#  'Pioneer',
#  'Pioneertown',
#  'Piru',
#  'Pixley',
#  'Planada',
#  'Platina',
#  'Playa Del Rey',
#  'Pleasant Grove',
#  'Point Reyes Station',
#  'Pollock Pines',
#  'Pope Valley',
#  'Port Costa',
#  'Porter Ranch',
#  'Posey',
#  'Potrero',
#  'Potter Valley',
#  'Prather',
#  'Princeton',
#  'Quincy',
#  'Raisin City',
#  'Ramona',
#  'Ranchita',
#  'Rancho Santa Fe',
#  'Randsburg',
#  'Ravendale',
#  'Raymond',
#  'Redcrest',
#  'Redway',
#  'Redwood Valley',
#  'Rescue',
#  'Reseda',
#  'Richgrove',
#  'Richvale',
#  'Rio Linda',
#  'Rio Nido',
#  'Rio Oso',
#  'River Pines',
#  'Riverdale',
#  'Rodeo',
#  'Rosamond',
#  'Rough And Ready',
#  'Round Mountain',
#  'Rowland Heights',
#  'Running Springs',
#  'Saint Helena',
#  'Salida',
#  'Salton City',
#  'Salyer',
#  'Samoa',
#  'San Andreas',
#  'San Ardo',
#  'San Geronimo',
#  'San Gregorio',
#  'San Lorenzo',
#  'San Lucas',
#  'San Martin',
#  'San Miguel',
#  'San Pedro',
#  'San Quentin',
#  'San Simeon',
#  'San Ysidro',
#  'Santa Margarita',
#  'Santa Ynez',
#  'Santa Ysabel',
#  'Scotia',
#  'Scott Bar',
#  'Seeley',
#  'Seiad Valley',
#  'Sequoia National Park',
#  'Shandon',
#  'Shasta',
#  'Shaver Lake',
#  'Sheep Ranch',
#  'Sheridan',
#  'Sherman Oaks',
#  'Shingle Springs',
#  'Shingletown',
#  'Shoshone',
#  'Sierra City',
#  'Sierraville',
#  'Silverado',
#  'Sloughhouse',
#  'Smartville',
#  'Smith River',
#  'Snelling',
#  'Soda Springs',
#  'Somerset',
#  'Somes Bar',
#  'Somis',
#  'Soquel',
#  'Soulsbyville',
#  'South Dos Palos',
#  'Spreckels',
#  'Spring Valley',
#  'Springville',
#  'Squaw Valley',
#  'Standish',
#  'Stanford',
#  'Stevenson Ranch',
#  'Stevinson',
#  'Stinson Beach',
#  'Stirling City',
#  'Stonyford',
#  'Stratford',
#  'Strathmore',
#  'Strawberry Valley',
#  'Studio City',
#  'Sugarloaf',
#  'Sultana',
#  'Summerland',
#  'Sun City',
#  'Sun Valley',
#  'Sunland',
#  'Sunol',
#  'Sunset Beach',
#  'Surfside',
#  'Sutter',
#  'Sylmar',
#  'Tahoe City',
#  'Tahoe Vista',
#  'Tahoma',
#  'Tarzana',
#  'Taylorsville',
#  'Tecate',
#  'Tecopa',
#  'Templeton',
#  'Termo',
#  'Terra Bella',
#  'The Sea Ranch',
#  'Thermal',
#  'Thornton',
#  'Thousand Palms',
#  'Three Rivers',
#  'Tipton',
#  'Tollhouse',
#  'Tomales',
#  'Topanga',
#  'Topaz',
#  'Trabuco Canyon',
#  'Tranquillity',
#  'Traver',
#  'Travis Afb',
#  'Trinity Center',
#  'Trona',
#  'Tujunga',
#  'Tuolumne',
#  'Tupman',
#  'Twain',
#  'Twain Harte',
#  'Twin Bridges',
#  'Upper Lake',
#  'Valencia',
#  'Vallecito',
#  'Valley Center',
#  'Valley Ford',
#  'Valley Springs',
#  'Valley Village',
#  'Valyermo',
#  'Van Nuys',
#  'Venice',
#  'Ventura',
#  'Vernalis',
#  'Vidal',
#  'Vina',
#  'Volcano',
#  'Wallace',
#  'Walnut Grove',
#  'Warner Springs',
#  'Washington',
#  'Weaverville',
#  'Weimar',
#  'Weldon',
#  'Wendel',
#  'Weott',
#  'West Hills',
#  'West Point',
#  'Westley',
#  'Westport',
#  'Westwood',
#  'White Water',
#  'Whitethorn',
#  'Whitmore',
#  'Willow Creek',
#  'Wilmington',
#  'Wilseyville',
#  'Wilton',
#  'Winchester',
#  'Winnetka',
#  'Winterhaven',
#  'Winton',
#  'Wishon',
#  'Witter Springs',
#  'Wofford Heights',
#  'Woodacre',
#  'Woodbridge',
#  'Woodland Hills',
#  'Woody',
#  'Wrightwood',
#  'Yermo',
#  'Yorkville',
#  'Yosemite National Park',
#  'Zenia',
#  nan}

# %%
#Code task 16#
#Check on the number of cities that are in cust_churn but not in california_cities
len(missing_cities)
# Out:
# 689

# %% [markdown]
# ##Checking for some missing values ​​reveals that these are territorial divisions used by the census bureau:
# - Census-designated place : CDP
# - Census County Division : C
# - Unincorporated community : UNINCD
# Additionally, historical naming conventions differentiate between cities and to
#
# It is indicated to:
# - rename the City column by Name_place
# - insert a new column that specifies the differences between the different placeswns

# %%
#Code task 17#
#Downloading the list of Census-designated place (CDP), Census County Division(CCD), Cities and towns in California
#This list contains more places than the precedent list but less features
california_divi_terr = pd.read_csv("C:/Users/wgerm/OneDrive/Documents/GitHub/wgermain24/archive CHURN/California_county_cities.csv")

# %%
#Code task 18#
#Call the head method on new DataFrame to print several rows
california_divi_terr.head()
# Out:
#                    Name          Name_concat_type Entity Type          County
# 0              Berkeley              Berkeley CCD         CCD  Alameda County
# 1        Fremont-Newark        Fremont-Newark CCD         CCD  Alameda County
# 2               Hayward               Hayward CCD         CCD  Alameda County
# 3  Livermore-Pleasanton  Livermore-Pleasanton CCD         CCD  Alameda County
# 4               Oakland               Oakland CCD         CCD  Alameda County

# %%
#Code task 19#
#Check the labels of the columns using the columns method
california_divi_terr.columns
# Out:
# Index(['Name', 'Name_concat_type', 'Entity Type', 'County'], dtype='object')

# %%
#Code task 20#
#Same code as code 15 but now with the new more complete California location DataFrame
#Find the cities in `cust_churn` that are not in `california_cities`
#Using: set(list1) - set(list2) is an easy way to get items in list1 that are not in list2
missing_cities2 = set(cust_churn.City) - set(california_divi_terr.Name)
missing_cities2
# Out:
# {'Woodland Hills', 'Yosemite National Park'}

# %%
#Code task 21#
#Check the number of cities in cust_churn that are note in the official territorial division
len(missing_cities2)
# Out:
# 2

# %% [markdown]
# Only two cities in cust_churn were not identified as being part of California's territorial divisions. In fact, these are public places that will be manually recorded as "pla" (stand for place)

# %%
#Code task 22#
#Create a new DataFrame by merging the DataFrame Cust_churn and the DataFrame california_divi_terr
#call the head method to print several row after the merging

df_cust_churn = pd.merge(cust_churn,california_divi_terr, left_on = 'City', right_on ='Name')
df_cust_churn.head()
# Out:
#    CustomerID  Count         City  Zip Code                Lat Long  \
# 0  3668-QPYBK    1.0  Los Angeles   90003.0  33.964131, -118.272783
# 1  3668-QPYBK    1.0  Los Angeles   90003.0  33.964131, -118.272783
# 2  3668-QPYBK    1.0  Los Angeles   90003.0  33.964131, -118.272783
# 3  9237-HQITU    1.0  Los Angeles   90005.0   34.059281, -118.30742
# 4  9237-HQITU    1.0  Los Angeles   90005.0   34.059281, -118.30742
#
#     Latitude   Longitude  Gender Senior Citizen Partner  ... Total Charges  \
# 0  33.964131 -118.272783    Male             No      No  ...        108.15
# 1  33.964131 -118.272783    Male             No      No  ...        108.15
# 2  33.964131 -118.272783    Male             No      No  ...        108.15
# 3  34.059281 -118.307420  Female             No      No  ...        151.65
# 4  34.059281 -118.307420  Female             No      No  ...        151.65
#
#    Churn Label Churn Value Churn Score    CLTV                  Churn Reason  \
# 0          Yes         1.0        86.0  3239.0  Competitor made better offer
# 1          Yes         1.0        86.0  3239.0  Competitor made better offer
# 2          Yes         1.0        86.0  3239.0  Competitor made better offer
# 3          Yes         1.0        67.0  2701.0                         Moved
# 4          Yes         1.0        67.0  2701.0                         Moved
#
#           Name  Name_concat_type Entity Type               County
# 0  Los Angeles   Los Angeles CCD         CCD   Los Angeles County
# 1  Los Angeles  Los Angeles CDP          CDP   Los Angeles County
# 2  Los Angeles      Los Angeles          CIT   Los Angeles County
# 3  Los Angeles   Los Angeles CCD         CCD   Los Angeles County
# 4  Los Angeles  Los Angeles CDP          CDP   Los Angeles County
#
# [5 rows x 35 columns]

# %% [markdown]
# 2.2.4 Distribution of Churn by City

# %%
#Code task 23#
#Use of the pattern dataframe.groupby to determine the number of churn by City
Churn_city = df_cust_churn.groupby('City')['Churn Label'].sum()
Churn_city
# Out:
# City
# Acampo                                   YesYesYesNo
# Acton                                       NoNoNoNo
# Adelanto                                 YesNoNoNoNo
# Adin                                      YesYesNoNo
# Agoura Hills                            YesYesNoNoNo
#                                 ...
# Yreka                               NoNoNoNoNoNoNoNo
# Yuba City       YesYesYesYesNoNoNoNoNoNoNoNoNoNoNoNo
# Yucaipa                           YesYesNoNoNoNoNoNo
# Yucca Valley                              NoNoNoNoNo
# Zenia                                      YesNoNoNo
# Name: Churn Label, Length: 1127, dtype: object

# %% [markdown]
# The concatenation of values ​​suggests that "Yes" and "No" are stored as string values, not boolean values ​​in the column named "Churn Label". They should be checked in all other columns where they appear and converted if necessary.

# %%
#Code task 24#
# Define the mapping and apply it to the selected columns
#Lisf of columns with the same pattern
#Call the info method to get a preview of the columns after performing the mapping
mapping = {'Yes': True, 'No': False}
column_to_convert = ['Senior Citizen', 'Partner', 'Dependents','Phone Service', 'Multiple Lines','Online Security','Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies','Paperless Billing', 'Churn Label']
df_cust_churn[column_to_convert] = df_cust_churn[column_to_convert].map(lambda x: mapping.get(x, False))

df_cust_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11782 entries, 0 to 11781
# Data columns (total 35 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         11779 non-null  object
#  1   Count              11779 non-null  float64
#  2   City               11779 non-null  object
#  3   Zip Code           11779 non-null  float64
#  4   Lat Long           11779 non-null  object
#  5   Latitude           11779 non-null  float64
#  6   Longitude          11779 non-null  float64
#  7   Gender             11779 non-null  object
#  8   Senior Citizen     11782 non-null  bool
#  9   Partner            11782 non-null  bool
#  10  Dependents         11782 non-null  bool
#  11  Tenure Months      11779 non-null  float64
#  12  Phone Service      11782 non-null  bool
#  13  Multiple Lines     11782 non-null  bool
#  14  Internet Service   11779 non-null  object
#  15  Online Security    11782 non-null  bool
#  16  Online Backup      11782 non-null  bool
#  17  Device Protection  11782 non-null  bool
#  18  Tech Support       11782 non-null  bool
#  19  Streaming TV       11782 non-null  bool
#  20  Streaming Movies   11782 non-null  bool
#  21  Contract           11779 non-null  object
#  22  Paperless Billing  11782 non-null  bool
#  23  Payment Method     11779 non-null  object
#  24  Monthly Charges    11779 non-null  float64
#  25  Total Charges      11779 non-null  object
#  26  Churn Label        11782 non-null  bool
#  27  Churn Value        11781 non-null  float64
#  28  Churn Score        11779 non-null  float64
#  29  CLTV               11779 non-null  float64
#  30  Churn Reason       3159 non-null   object
#  31  Name               11779 non-null  object
#  32  Name_concat_type   11782 non-null  object
#  33  Entity Type        11782 non-null  object
#  34  County             11778 non-null  object
# dtypes: bool(13), float64(9), object(13)
# memory usage: 2.1+ MB

# %%
#Code task 25#
#Check the contents of one of the columns ('Churn Label') 
print(df_cust_churn['Churn Label'])
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 11777    False
# 11778    False
# 11779    False
# 11780    False
# 11781    False
# Name: Churn Label, Length: 11782, dtype: bool

# %%
#Code task 26#
#Similar with code task 23 after converting the colummns from dtype Object to the dtype bool
Churn_city  = df_cust_churn.groupby('City')['Churn Label'].sum()
Churn_city
# Out:
# City
# Acampo          3
# Acton           0
# Adelanto        1
# Adin            2
# Agoura Hills    2
#                ..
# Yreka           0
# Yuba City       4
# Yucaipa         2
# Yucca Valley    0
# Zenia           1
# Name: Churn Label, Length: 1127, dtype: int64

# %% [markdown]
# The test on the column 'Churn Label' confirm that the column had converted properly from dtype 'string' to dtype 'Boolean'

# %% [markdown]
# 2.2.5 Numeric values register as Object
#
# Total Charges is a numeric value but appear as an object. This column have to correct

# %%
#Code task 27#
#Check the "Total Charges" column to get an idea of ​​what might explain the object data type attribute
print(df_cust_churn['Total Charges'])
# Out:
# 0        108.15
# 1        108.15
# 2        108.15
# 3        151.65
# 4        151.65
#           ...
# 11777    346.45
# 11778    6844.5
# 11779       NaN
# 11780       NaN
# 11781       NaN
# Name: Total Charges, Length: 11782, dtype: object

# %%
#Code task 28# 
# Replace empty strings with NaN as the column might be recognized as an object type because of Non-numeric characters mixed in with numbers, Missing values (NaN or None) or Spaces or other formatting issues.
df_cust_churn['Total Charges'].replace('', np.nan, inplace=True)
# Out:
# C:\Users\wgerm\AppData\Local\Temp\ipykernel_47472\3570579900.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cust_churn['Total Charges'].replace('', np.nan, inplace=True)

# %%
#Code task 29#
# Convert to numeric, forcing errors to NaN
df_cust_churn['Total Charges'] = pd.to_numeric(cust_churn['Total Charges'], errors='coerce')

# %%
#Code task 30#
#Check the new type
print(df_cust_churn['Total Charges'].dtype)
# Out:
# float64

# %% [markdown]
# The "Total Charges" column has been converted from dtype Object to numeric

# %%
#Code task 31#
#Check on the column 'Internet Service'
df_cust_churn['Internet Service'].value_counts().head()
# Out:
# Internet Service
# Fiber optic    5139
# DSL            4097
# No             2543
# Name: count, dtype: int64

# %%
#Code task 32#
#Check on the column 'Contract'
df_cust_churn['Contract'].value_counts().head()
# Out:
# Contract
# Month-to-month    6530
# Two year          2794
# One year          2455
# Name: count, dtype: int64

# %%
#Code task 33#
#Check on the column 'Payment Method'
df_cust_churn['Payment Method'].value_counts().head()
# Out:
# Payment Method
# Electronic check             3977
# Mailed check                 2716
# Credit card (automatic)      2554
# Bank transfer (automatic)    2532
# Name: count, dtype: int64

# %%
#Code task 34#
#Check on the column 'Churn Reason'
df_cust_churn['Churn Reason'].value_counts().head()
# Out:
# Churn Reason
# Competitor offered higher download speeds    339
# Attitude of support person                   312
# Competitor offered more data                 284
# Don't know                                   263
# Competitor made better offer                 236
# Name: count, dtype: int64

# %% [markdown]
# 2.3 Numeric Features

# %% [markdown]
# 2.3.1 Numeric data

# %%
##Code task 35#
#Call the describe method for a statistical summary of the numerical columns
df_cust_churn.describe().T
# Out:
#                    count          mean          std           min  \
# Count            11779.0      1.000000     0.000000      1.000000
# Zip Code         11779.0  93383.049410  1922.777070  90001.000000
# Latitude         11779.0     36.137781     2.411061     32.555828
# Longitude        11779.0   -119.749765     2.128376   -124.301372
# Tenure Months    11779.0     32.213685    24.485594      0.000000
# Monthly Charges  11779.0     64.680805    30.085892     18.250000
# Total Charges     7032.0   2283.300441  2266.771362     18.800000
# Churn Value      11781.0      0.426727    17.213426      0.000000
# Churn Score      11779.0     58.881144    21.469308      5.000000
# CLTV             11779.0   4396.888276  1182.280767   2003.000000
#
#                           25%           50%           75%           max
# Count                1.000000      1.000000      1.000000      1.000000
# Zip Code         92016.500000  93460.000000  95247.000000  96161.000000
# Latitude            34.011755     35.916943     38.044523     41.962127
# Longitude         -121.759537   -119.513163   -118.078097   -114.192901
# Tenure Months        9.000000     29.000000     55.000000     72.000000
# Monthly Charges     35.650000     70.200000     89.850000    118.750000
# Total Charges      401.450000   1397.475000   3794.737500   8684.800000
# Churn Value          0.000000      0.000000      1.000000   1868.000000
# Churn Score         41.000000     61.000000     76.000000    100.000000
# CLTV              3460.000000   4521.000000   5375.000000   6500.000000

# %% [markdown]
# 2.3.2 Distribution Of Features Values

# %%
##Code task 36#
#Call cust_churn's 'hist' method to plot histagrams of each of the numeric features
df_cust_churn.hist(figsize = (15,10))
# Out:
# array([[<Axes: title={'center': 'Count'}>,
#         <Axes: title={'center': 'Zip Code'}>,
#         <Axes: title={'center': 'Latitude'}>],
#        [<Axes: title={'center': 'Longitude'}>,
#         <Axes: title={'center': 'Tenure Months'}>,
#         <Axes: title={'center': 'Monthly Charges'}>],
#        [<Axes: title={'center': 'Total Charges'}>,
#         <Axes: title={'center': 'Churn Value'}>,
#         <Axes: title={'center': 'Churn Score'}>],
#        [<Axes: title={'center': 'CLTV'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# #Features with possible cause for concern about :
# #- "Montly Charges" because of the concentration of values observed at the start of the normal curve. This can be explain by the fact most of people #choose the lowest price plan
# #- "Tenure Months" because of the high number below 30. This is the problem that we have to solve.
#
# #Conclusion: Features do not present any problem at firt glance

# %% [markdown]
# Drop Rows With No 'Churn Label' Data

# %%
#Code task  37# 
#Rows with missing values for the independant variable

cust_churn['Churn Label'].isnull().sum()
# Out:
# 3

# %% [markdown]
# #There is no need to remove any row.

# %% [markdown]
# Some statistics related to "Tenure Months" and Churn Label, the indepedant variable

# %%
#Code task 38#
#Determine the average customer retention period;
#Determine the median customer retention period;
#Determine the maximum customer retention period;
#Calculate the quantile 75%
#Calculate the quantile 25%
#group the above results into one line
mean_tenure = pd.Series(df_cust_churn['Tenure Months'].mean(), name='Mean')
median_tenure = pd.Series(df_cust_churn['Tenure Months'].median(), name='Median')
max_tenure = pd.Series(df_cust_churn['Tenure Months'].max(), name='Max')
quantile_75 = pd.Series(df_cust_churn['Tenure Months'].quantile(0.75), name='Q(75)')
quantile_25 = pd.Series(df_cust_churn['Tenure Months'].quantile(0.25), name='Q25')
# Concatenate Series into a DataFrame
churn_stat = pd.concat([mean_tenure, median_tenure, max_tenure,quantile_75,quantile_25], axis=1)

print(churn_stat)
# Out:
#         Mean  Median   Max  Q(75)  Q25
# 0  32.213685    29.0  72.0   55.0  9.0

# %%
#Code task 39#
#Distribution of customers, according to 'Tenure Months'
#Determine first the number of custumers by 'Tenure
#Convert the Series in a DataFrame by the frame method
#Add a new column in the precedent DataFrame
df_cust_churn_tenure = df_cust_churn.groupby('Tenure Months')['Tenure Months'].count().sort_values(ascending=False)
df_cust_churn_tenure2 = df_cust_churn_tenure.to_frame()
df_cust_churn_tenure2['%']= 100* df_cust_churn_tenure/df_cust_churn['Tenure Months'].count()
df_cust_churn_tenure2.head(15)
# Out:
#                Tenure Months         %
# Tenure Months
# 1.0                     1035  8.786824
# 72.0                     596  5.059852
# 2.0                      374  3.175142
# 3.0                      324  2.750658
# 71.0                     290  2.462009
# 4.0                      289  2.453519
# 5.0                      234  1.986586
# 7.0                      226  1.918669
# 8.0                      213  1.808303
# 9.0                      209  1.774344
# 10.0                     198  1.680958
# 12.0                     194  1.646999
# 70.0                     190  1.613040
# 6.0                      189  1.604550
# 13.0                     186  1.579081

# %% [markdown]
# 2.5 Number of churn by gender

# %%
#Code task 40#
# Is the genre influence the tend to churn?
#Concatenate with pd.concat the customers by gender and Churn Label and then calculate the percentage by gender
gender_churn_sum = pd.concat([df_cust_churn.groupby('Gender')['Gender'].count(),df_cust_churn.groupby('Gender')['Churn Label'].sum()],axis=1)
gender_churn_sum["%"]=100*gender_churn_sum['Churn Label']/gender_churn_sum['Gender']
gender_churn_sum
# Out:
#         Gender  Churn Label          %
# Gender
# Female    5823         1599  27.460072
# Male      5956         1560  26.192075

# %% [markdown]
# Gender does not appear to be relevant in determining whether a customer will churn.

# %% [markdown]
# 2.6 Remove Missing Values

# %%
#Code task 41#
#Check the shape of the DataFrame before remove rows
df_cust_churn.shape
# Out:
# (11782, 35)

# %%
print(df_cust_churn.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11782 entries, 0 to 11781
# Data columns (total 35 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         11779 non-null  object
#  1   Count              11779 non-null  float64
#  2   City               11779 non-null  object
#  3   Zip Code           11779 non-null  float64
#  4   Lat Long           11779 non-null  object
#  5   Latitude           11779 non-null  float64
#  6   Longitude          11779 non-null  float64
#  7   Gender             11779 non-null  object
#  8   Senior Citizen     11782 non-null  bool
#  9   Partner            11782 non-null  bool
#  10  Dependents         11782 non-null  bool
#  11  Tenure Months      11779 non-null  float64
#  12  Phone Service      11782 non-null  bool
#  13  Multiple Lines     11782 non-null  bool
#  14  Internet Service   11779 non-null  object
#  15  Online Security    11782 non-null  bool
#  16  Online Backup      11782 non-null  bool
#  17  Device Protection  11782 non-null  bool
#  18  Tech Support       11782 non-null  bool
#  19  Streaming TV       11782 non-null  bool
#  20  Streaming Movies   11782 non-null  bool
#  21  Contract           11779 non-null  object
#  22  Paperless Billing  11782 non-null  bool
#  23  Payment Method     11779 non-null  object
#  24  Monthly Charges    11779 non-null  float64
#  25  Total Charges      7032 non-null   float64
#  26  Churn Label        11782 non-null  bool
#  27  Churn Value        11781 non-null  float64
#  28  Churn Score        11779 non-null  float64
#  29  CLTV               11779 non-null  float64
#  30  Churn Reason       3159 non-null   object
#  31  Name               11779 non-null  object
#  32  Name_concat_type   11782 non-null  object
#  33  Entity Type        11782 non-null  object
#  34  County             11778 non-null  object
# dtypes: bool(13), float64(10), object(12)
# memory usage: 2.1+ MB
# None

# %%
#Code task 42#
#Count the number of missing values for the column 'CustomerID"
df_cust_churn['CustomerID'].isnull().sum()
# Out:
# 3

# %%
#Code task 43#
#Remove rows with  missing values in the columns CustomerID and Churn label
df_cust_churn_cleaned = df_cust_churn.dropna(subset =['CustomerID','Churn Label'])

# %%
#Code task 44#
#Check the Shape of the new DataFrame
df_cust_churn_cleaned.shape
# Out:
# (11779, 35)

# %%
#Code task 45#
#Call the method info to get an overview of the DataFrame
df_cust_churn_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11779 entries, 0 to 11778
# Data columns (total 35 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         11779 non-null  object
#  1   Count              11779 non-null  float64
#  2   City               11779 non-null  object
#  3   Zip Code           11779 non-null  float64
#  4   Lat Long           11779 non-null  object
#  5   Latitude           11779 non-null  float64
#  6   Longitude          11779 non-null  float64
#  7   Gender             11779 non-null  object
#  8   Senior Citizen     11779 non-null  bool
#  9   Partner            11779 non-null  bool
#  10  Dependents         11779 non-null  bool
#  11  Tenure Months      11779 non-null  float64
#  12  Phone Service      11779 non-null  bool
#  13  Multiple Lines     11779 non-null  bool
#  14  Internet Service   11779 non-null  object
#  15  Online Security    11779 non-null  bool
#  16  Online Backup      11779 non-null  bool
#  17  Device Protection  11779 non-null  bool
#  18  Tech Support       11779 non-null  bool
#  19  Streaming TV       11779 non-null  bool
#  20  Streaming Movies   11779 non-null  bool
#  21  Contract           11779 non-null  object
#  22  Paperless Billing  11779 non-null  bool
#  23  Payment Method     11779 non-null  object
#  24  Monthly Charges    11779 non-null  float64
#  25  Total Charges      7032 non-null   float64
#  26  Churn Label        11779 non-null  bool
#  27  Churn Value        11779 non-null  float64
#  28  Churn Score        11779 non-null  float64
#  29  CLTV               11779 non-null  float64
#  30  Churn Reason       3159 non-null   object
#  31  Name               11779 non-null  object
#  32  Name_concat_type   11779 non-null  object
#  33  Entity Type        11779 non-null  object
#  34  County             11775 non-null  object
# dtypes: bool(13), float64(10), object(12)
# memory usage: 2.2+ MB

# %%
county_null = df_cust_churn[df_cust_churn['County'].isnull()]
county_null
# Out:
#        CustomerID  Count     City  Zip Code                Lat Long  \
# 490    6166-ILMNY    1.0  Tomales   94971.0  38.240769, -122.901041
# 6552   4635-EJYPD    1.0  Tomales   94971.0  38.240769, -122.901041
# 8562   2718-YSKCS    1.0  Tomales   94971.0  38.240769, -122.901041
# 10544  4770-QAZXN    1.0  Tomales   94971.0  38.240769, -122.901041
#
#         Latitude   Longitude  Gender  Senior Citizen  Partner  ...  \
# 490    38.240769 -122.901041  Female           False    False  ...
# 6552   38.240769 -122.901041    Male           False     True  ...
# 8562   38.240769 -122.901041    Male           False     True  ...
# 10544  38.240769 -122.901041  Female           False    False  ...
#
#        Total Charges  Churn Label  Churn Value  Churn Score    CLTV  \
# 490           247.25         True          1.0         68.0  5667.0
# 6552          788.55        False          0.0         49.0  4735.0
# 8562             NaN        False          0.0         56.0  6444.0
# 10544            NaN        False          0.0         54.0  2783.0
#
#                        Churn Reason     Name  Name_concat_type  Entity Type  \
# 490    Competitor offered more data  Tomales           Tomales         UNIN
# 6552                            NaN  Tomales           Tomales         UNIN
# 8562                            NaN  Tomales           Tomales         UNIN
# 10544                           NaN  Tomales           Tomales         UNIN
#
#        County
# 490       NaN
# 6552      NaN
# 8562      NaN
# 10544     NaN
#
# [4 rows x 35 columns]

# %%
df_cust_churn_cleaned.loc[df_cust_churn_cleaned['Name'] == 'Tomales','County'] = 'Marin'

# %%
df_cust_churn_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11779 entries, 0 to 11778
# Data columns (total 35 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         11779 non-null  object
#  1   Count              11779 non-null  float64
#  2   City               11779 non-null  object
#  3   Zip Code           11779 non-null  float64
#  4   Lat Long           11779 non-null  object
#  5   Latitude           11779 non-null  float64
#  6   Longitude          11779 non-null  float64
#  7   Gender             11779 non-null  object
#  8   Senior Citizen     11779 non-null  bool
#  9   Partner            11779 non-null  bool
#  10  Dependents         11779 non-null  bool
#  11  Tenure Months      11779 non-null  float64
#  12  Phone Service      11779 non-null  bool
#  13  Multiple Lines     11779 non-null  bool
#  14  Internet Service   11779 non-null  object
#  15  Online Security    11779 non-null  bool
#  16  Online Backup      11779 non-null  bool
#  17  Device Protection  11779 non-null  bool
#  18  Tech Support       11779 non-null  bool
#  19  Streaming TV       11779 non-null  bool
#  20  Streaming Movies   11779 non-null  bool
#  21  Contract           11779 non-null  object
#  22  Paperless Billing  11779 non-null  bool
#  23  Payment Method     11779 non-null  object
#  24  Monthly Charges    11779 non-null  float64
#  25  Total Charges      7032 non-null   float64
#  26  Churn Label        11779 non-null  bool
#  27  Churn Value        11779 non-null  float64
#  28  Churn Score        11779 non-null  float64
#  29  CLTV               11779 non-null  float64
#  30  Churn Reason       3159 non-null   object
#  31  Name               11779 non-null  object
#  32  Name_concat_type   11779 non-null  object
#  33  Entity Type        11779 non-null  object
#  34  County             11779 non-null  object
# dtypes: bool(13), float64(10), object(12)
# memory usage: 2.2+ MB

# %%
df_cust_churn_cleaned.columns
# Out:
# Index(['CustomerID', 'Count', 'City', 'Zip Code', 'Lat Long', 'Latitude',
#        'Longitude', 'Gender', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure Months', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn Label',
#        'Churn Value', 'Churn Score', 'CLTV', 'Churn Reason', 'Name',
#        'Name_concat_type', 'Entity Type', 'County'],
#       dtype='object')

# %%
df_churn = df_cust_churn_cleaned[['CustomerID', 'Count', 'Zip Code',
       'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen',
       'Partner', 'Dependents', 'Tenure Months', 'Phone Service',
       'Multiple Lines', 'Internet Service', 'Online Security',
       'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
       'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
       'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value',
       'Churn Score', 'CLTV', 'Churn Reason', 'Name', 'Name_concat_type',
       'Entity Type', 'County']]

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11779 entries, 0 to 11778
# Data columns (total 34 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         11779 non-null  object
#  1   Count              11779 non-null  float64
#  2   Zip Code           11779 non-null  float64
#  3   Lat Long           11779 non-null  object
#  4   Latitude           11779 non-null  float64
#  5   Longitude          11779 non-null  float64
#  6   Gender             11779 non-null  object
#  7   Senior Citizen     11779 non-null  bool
#  8   Partner            11779 non-null  bool
#  9   Dependents         11779 non-null  bool
#  10  Tenure Months      11779 non-null  float64
#  11  Phone Service      11779 non-null  bool
#  12  Multiple Lines     11779 non-null  bool
#  13  Internet Service   11779 non-null  object
#  14  Online Security    11779 non-null  bool
#  15  Online Backup      11779 non-null  bool
#  16  Device Protection  11779 non-null  bool
#  17  Tech Support       11779 non-null  bool
#  18  Streaming TV       11779 non-null  bool
#  19  Streaming Movies   11779 non-null  bool
#  20  Contract           11779 non-null  object
#  21  Paperless Billing  11779 non-null  bool
#  22  Payment Method     11779 non-null  object
#  23  Monthly Charges    11779 non-null  float64
#  24  Total Charges      7032 non-null   float64
#  25  Churn Label        11779 non-null  bool
#  26  Churn Value        11779 non-null  float64
#  27  Churn Score        11779 non-null  float64
#  28  CLTV               11779 non-null  float64
#  29  Churn Reason       3159 non-null   object
#  30  Name               11779 non-null  object
#  31  Name_concat_type   11779 non-null  object
#  32  Entity Type        11779 non-null  object
#  33  County             11779 non-null  object
# dtypes: bool(13), float64(10), object(11)
# memory usage: 2.1+ MB

# %%
#2.7 Save data
#Save the data to new csv file
datapath = "C:/Users/wgerm/OneDrive/Documents/GitHub/Capstone 2 - Step 3/df_cust_churn_cleaned.csv"
df_churn.to_csv(datapath, index=False)

# %% [markdown]
# 2.8 Summary
